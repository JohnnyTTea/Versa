# %%
import csv
import pandas as pd

# %%
array=[1,2,3,0,5]
array[:-3]
# Out:
# [1, 2]

# %%
df=pd.read_csv('../AIS Sales Report 2023-04-13.csv')
df
# Out:
#                    itemno                               desc1  onhand  Jan  \
# 0          BLR-HC064RR-PP    Add Description to OMS, Need Pix       0    1
# 1               EM-JAF-BK    Add Description to OMS, Need Pix       0    0
# 2               EM-JAF-BL    Add Description to OMS, Need Pix       0    0
# 3                EM-JAF-R    Add Description to OMS, Need Pix       0    0
# 4           ..3PLSHIPPING    SERVICE 3RD PARTY SHIPPING LABEL     -41   15
# ...                   ...                                 ...     ...  ...
# 70117  ZDS-BLF-CCORV06ZR1    Add Description to OMS, Need Pix       0    0
# 70118    ZDS-BLF-LI300TRD  01-05 Lexus IS300 TRD Style Bumper       1    0
# 70119    ZDS-BLF-SBRZ13CS    13-15 Subaru BRZ CS Style Bumper       1    0
# 70120    ZDS-BLF-SFRS13CS       13-14 Scion FRS GT86 DS Style       1    0
# 70121         ZDSBLF-BZ3A    Add Description to OMS, Need Pix       0    0
#
#        Feb  Mar  Apr  May  Jun     average  total
# ...
